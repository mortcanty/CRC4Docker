# %%
# %matplotlib inline

# %%
ls imagery
# Out:
# 20010525*            asterslope.tif     pickering_ms_pan_atwt
# 20010525.hdr*        cosgamma           pickering_ms_pan_atwt.hdr
# 20010626*            cosgamma.hdr       pickering_ms_pan_dwt
# 20010626_canny       dem_aspect         pickering_ms_pan_dwt.hdr
# 20010626_canny.hdr   dem_slope          pickering_ms_pan.hdr
# 20010626_corner      dem_temp           pickering_pan
# 20010626_corner.hdr  dem_temp.hdr       pickering_pan.hdr
# 20010626.hdr*        may0107*           slope.tif
# 20090829_enl.tif     may0107.hdr*       temporalfiltered.tif
# 20090829_gamma.tif   may0107pca.tfw*    train_.dbf*
# 20090829_mmse.tif    may0107pca.tif*    train.dbf*
# 20090829.tif         nir_band           train_.evf*
# 3N_subset            nir_band.hdr       train.prj*
# 3N_subset_corr       pca.tif*           train.roi*
# 3N_subset_corr.hdr   pickering1_ms      train.shp*
# 3N_subset.hdr        pickering1_ms.hdr  train.shx*
# asteraspect.tif      pickering_ms       train.txt*
# ...

# %%
run scripts/registerms -d [100,100,800,800] imagery/20010525 imagery/20010626
# Out:
# --------------------------------
#         Register
# ---------------------------------
# Sun Mar 11 15:54:26 2018
# reference image: imagery/20010525
# warp image: imagery/20010626
# warp band: 1
# Warped image written to: imagery/20010626_warp
# elapsed time: 3.63198208809
# Warped image written to: imagery/20010626_warp

# %%
run scripts/dispms -f imagery/20010626_warp -e 3 -p [4,5,6] \
-F imagery/20010525 -D [100,100,800,800] -E 3 -P [4,5,6]
