# %%
# %matplotlib inline

# %%
ls imagery
# Out:
# may0107pca_class.tif           train_.dbf*  train.prj*  train.shx*
# may0107pca_NNet(Backprop).tst  train.dbf*   train.roi*  train.txt*
# may0107pca.tif*                train_.evf*  train.shp*

# %%
run scripts/dispms -f imagery/may0107pca_class.tif -c
