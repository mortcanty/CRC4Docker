# %% [markdown]
# ## Ingested S1 SLC data
# ### Generate 2000x2000 spatial subsets

# %%
# %matplotlib inline

# %%
ls myimagery/S1_20180927
# Out:
# annotation/
# manifest.safe
# measurement/
# preview/
# S1_20180927_6x2_BL_PM.tif
# S1A_IW_SLC__1SDV_20180927T171606_20180927T171633_023887_029B6B_E1A4.SAFE-report-20180927T195149.pdf
# support/

# %%
run auxil/subset -d  [4500,4500,2000,2000] myimagery/S1_20180927/S1_20180927_6x2_BL_PM.tif
# Out:
# ...
# Spatial/spectral subsetting
# ...
# Thu May 16 12:05:21 2019
# Input myimagery/S1_20180927/S1_20180927_6x2_BL_PM.tif
# elapsed time: 5.49961090088
# Subset image written to: myimagery/S1_20180927/S1_20180927_6x2_BL_PM_sub.tif

# %%
run scripts/dispms -f myimagery/S1_20180822/S1_20180822_6x2_BL_PM_sub.tif -p [4,1,4]  -e 5

# %% [markdown]
# ### ENL estimation

# %%
run scripts/enlml -d [500,1250,400,400] myimagery/S1_20180530/S1_20180530_6x2_BL_PM_sub.tif
# Out:
# ...
#      ENL Estimation
# ...
# Thu May 16 15:10:49 2019
# infile:  myimagery/S1_20180530/S1_20180530_6x2_BL_PM_sub.tif
# Dual polarimetry
# filtering...
# row:  100  200  300
#  ENL image written to: myimagery/S1_20180530/S1_20180530_6x2_BL_PM_sub_enl.tif
# elapsed time: 12.4069011211

# %% [markdown]
# ### Sequential change algorithm

# %%
run scripts/sar_seqQ -d [400,400,1000,1000] -s 0.0001 -m  \
myimagery/series_6x2_BL_PM/S1_20180412_6x2_BL_PM_sub.tif \
myimagery/series_6x2_BL_PM/S1_20180424_6x2_BL_PM_sub.tif \
myimagery/series_6x2_BL_PM/S1_20180506_6x2_BL_PM_sub.tif \
myimagery/series_6x2_BL_PM/S1_20180518_6x2_BL_PM_sub.tif \
myimagery/series_6x2_BL_PM/S1_20180530_6x2_BL_PM_sub.tif \
myimagery/series_6x2_BL_PM/S1_20180611_6x2_BL_PM_sub.tif \
myimagery/series_6x2_BL_PM/S1_20180623_6x2_BL_PM_sub.tif \
myimagery/series_6x2_BL_PM/S1_20180705_6x2_BL_PM_sub.tif \
myimagery/series_6x2_BL_PM/S1_20180717_6x2_BL_PM_sub.tif \
myimagery/series_6x2_BL_PM/S1_20180729_6x2_BL_PM_sub.tif \
myimagery/series_6x2_BL_PM/S1_20180810_6x2_BL_PM_sub.tif \
myimagery/series_6x2_BL_PM/S1_20180822_6x2_BL_PM_sub.tif \
myimagery/series_6x2_BL_PM/S1_20180903_6x2_BL_PM_sub.tif \
myimagery/series_6x2_BL_PM/S1_20180915_6x2_BL_PM_sub.tif \
myimagery/series_6x2_BL_PM/S1_20180927_6x2_BL_PM_sub.tif \
change.tif 12.0

# %%
run scripts/dispms -f myimagery/series_6x2_BL_PM/change_fmap.tif -c
