# %%
# %matplotlib inline

# %%
run scripts/tf_imad  imagery/LE7_20010626 imagery/LE7_20010829
# Out:
# ------------IRMAD (tensorflow) -------------
# Fri Feb  8 15:50:54 2019
# first scene:  imagery/LE7_20010626
# second scene: imagery/LE7_20010829
# canonical corr: [0.99177403 0.97963583 0.92490207 0.86296352 0.74740675 0.6749103 ]
# MADs written to: imagery/MAD(LE7_20010626-LE7_20010829).tif
# elapsed time: 29.4328629971

# %%
run scripts/dispms -f imagery/MAD(LE7_20010626-LE7_20010829).tif -e 2  -p [1,2,3]

# %%
run scripts/iMadmap imagery/MAD(LE7_20010626-LE7_20010829).tif 0.00001
# Out:
# change map written to: imagery/MAD(LE7_20010626-LE7_20010829)_cmap.tif

# %%
run scripts/dispms -f imagery/MAD(LE7_20010626-LE7_20010829)_cmap.tif -e 3 -p [1,1,1]

# %%
# !tensorboard --logdir tf_logs/
