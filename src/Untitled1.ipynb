# %%
# %matplotlib inline

# %%
run scripts/dispms -f myimagery/LT5_19980329_sub.tif -e 3 -p [4,5,6]

# %%
run scripts/tf_imad myimagery/LT5_19980329_sub.tif myimagery/LT5_19980516_sub.tif
# Out:
# [0.99370216 0.96783911 0.93150642 0.87631112 0.85581331 0.46649314]
# MADs written to: myimagery/MAD(LT5_19980329_sub-LT5_19980516_sub).tif

# %%
run scripts/dispms -f myimagery/MAD(LT5_19980329_sub-LT5_19980516_sub).tif -e 3 -p [1,1,1]
