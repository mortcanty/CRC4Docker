# %%
# %matplotlib inline

# %%
run scripts/ex1_1 imagery/LE7_20010525 4

# %%
import auxil.auxil1 as auxil
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-9-b99f7386b159> in <module>
# ----> 1 import auxil.auxil1 as auxil
#
# ~/python/CRC4Docker/src/auxil/auxil1.py in <module>
#       9 import math, ctypes
#      10 from numpy.ctypeslib import ndpointer
# ---> 11 from scipy.special import betainc
#      12 from numpy.fft import fft2, ifft2, fftshift
#      13 import scipy.ndimage.interpolation as ndii
#
# ImportError: No module named 'scipy'
